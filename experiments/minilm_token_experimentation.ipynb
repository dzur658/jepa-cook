# %% [markdown]
# ## Check Representation Collapse
# The point of this notebook is to compare the representation diversity (cosine similarity) between the author's method (first 4 words) and the new Spacy verb extraction method.

# %% [markdown]
# Helper function to return embeddings of the model.

# %%
from sentence_transformers import SentenceTransformer

def get_embeddings(text):
    model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')
    return model.encode(text)
